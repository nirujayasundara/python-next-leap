# %% [markdown]
# <a href="https://colab.research.google.com/github/nirujayasundara/python-next-leap/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python String Methods

# %%
S="hello world"
print("capitalize:","hello".capitalize())
# Out:
# capitalize: Hello

# %%
print("casefold:",  "HELLO".casefold())
# Out:
# casefold: hello

# %%
print("center:", "hi". center(10,'*'))
# Out:
# center: ****hi****

# %%
s="hello world"
print("count:", s.count("0"))
# Out:
# count: 0

# %%
print ("encode:","hello".encode())
# Out:
# encode: b'hello'

# %%
s= "hello world"

print("endswith:", s .endswith("world"))
# Out:
# endswith: True

# %%
 print("expandtabs:", "hi/tthere" .expandtabs(4))
# Out:
# expandtabs: hi/tthere

# %%
s ="hello world"
print("find:", s.find("world"))
# Out:
# find: 6

# %%
print("format:","Hello {}" .format("Nirosha"))
# Out:
# format: Hello Nirosha

# %%
print("format_map:","Hi {Name}"  .format_map({"Name": "Nirosha"}))
# Out:
# format_map: Hi Nirosha

# %%
s ="hello world"
print("index:", s.index("world"))
# Out:
# index: 6

# %%
print("isalnum:","abc123".isalnum())
# Out:
# isalnum: True

# %%
print("isalpha:", "abc". isalpha())
# Out:
# isalpha: True

# %%
print("isascii:","123".isascii())
# Out:
# isascii: True

# %%
print("isdecimel:", "123".isdecimal())
# Out:
# isdecimel: True

# %%
print("isdigit:","123".isdigit())
# Out:
# isdigit: True

# %%
print("isidentifier:", "var_1".isidentifier())
# Out:
# isidentifier: True

# %%
print("Islower:","hello".islower())
# Out:
# Islower: True

# %%
print("isnumeric:","123".isnumeric())
# Out:
# isnumeric: True

# %%
print("isprintable:","hello".isprintable())
# Out:
# isprintable: True

# %%
print("isspace:","  ".isspace() )
# Out:
# isspace: True

# %%
print("istitle:", "Hello World" .istitle())
# Out:
# istitle: True

# %%
print("isupper:", "HELLO". isupper())
# Out:
# isupper: True

# %%
print("join:","_".join(["a","b"]))
# Out:
# join: a_b

# %%
print("ljust:","hi".ljust(6,'*'))
# Out:
# ljust: hi****

# %%
print("Hello" .lower())
# Out:
# hello

# %%
print("lstrip:," "hi".lstrip())
# Out:
# lstrip:,hi

# %%
print("partition:","hello world".partition(" "))
# Out:
# partition: ('hello', ' ', 'world')

# %%
print("removeprfeix:", "unhappy" .removeprefix("un"))
# Out:
# removeprfeix: happy

# %%
print("replace:", "hello".replace("l","x"))
# Out:
# replace: hexxo

# %%
print("removesuffix:", "file.txt" .removesuffix(".txt"))
# Out:
# removesuffix: file

# %%
s= "hello world"
print("rfind:", s.rfind("o"))
# Out:
# rfind: 7

# %%
s="hello world"
print("rindex:", s. rindex("o"))
# Out:
# rindex: 7

# %%
print("rjust:", "hi".rjust(6,'*'))
# Out:
# rjust: ****hi

# %%
print ("rpartition:", "hello world" .rpartition(" "))
# Out:
# rpartition: ('hello', ' ', 'world')

# %%
print("split:", "a,b,c" .split(","))
# Out:
# split: ['a', 'b', 'c']

# %%
print("splitlines:", "hi/nhello" .splitlines())
# Out:
# splitlines: ['hi/nhello']

# %%
s="hello world"
print("startswith:", s.startswith("hello"))
# Out:
# startswith: True

# %%
print("strip:","hi ".strip())
# Out:
# strip: hi

# %%
print("swapcase:", "Hello".swapcase())
# Out:
# swapcase: hELLO

# %%
print("title:","hello world".title())
# Out:
# title: Hello World

# %%
print("translate:","abc" . translate (str.maketrans("a","x")))
# Out:
# translate: xbc

# %%
print("upper:","hello" .upper())
# Out:
# upper: HELLO

# %%
print("zfill:", "5".zfill(3))
# Out:
# zfill: 005
